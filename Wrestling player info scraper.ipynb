# %% [markdown]
# # Website Scraper

# %% [markdown]
# This project will include a script that I will use in order to get the players info from the following websites:

# %% [markdown]
# We will then store the data in a dictionnary and transform that dictionnary into a dataframe

# %% [markdown]
# Once we have the dataframe, we will create a database to store the data

# %% [markdown]
# ### Importing modules

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# ### Setting up the scraper

# %%
url1='https://kohawkathletics.com/'
user_agent = "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:55.0) ' 'Gecko/20100101 ' 'Firefox/55.0"
headers = {'User-Agent': user_agent}

# %% [markdown]
# #### If the website contains multiple pages, create a loop to define the number of pages like this:

# %%
r=requests.get('https://kohawkathletics.com/sports/wrestling/roster')

# %%
soup=BeautifulSoup(r.content,'html.parser')

# %%
playerlist=soup.find_all('div', class_='sidearm-roster-player-other flex-item-1 columns hide-on-medium-down')

# %%
playerlinks=[]

# %%
for item in playerlist:
    for link in item.find_all('a',href=True):
        playerlinks.append(url1 + link['href'])

# %%
print(playerlinks)
# Out:
# ['https://kohawkathletics.com//sports/wrestling/roster/logan-andeway/7103', 'https://kohawkathletics.com//sports/wrestling/roster/mathieu-arsenault/7131', 'https://kohawkathletics.com//sports/wrestling/roster/wyatt-bieschke/7104', 'https://kohawkathletics.com//sports/wrestling/roster/aaron-castellanos/7105', 'https://kohawkathletics.com//sports/wrestling/roster/patrick-chambers/7106', 'https://kohawkathletics.com//sports/wrestling/roster/stone-cummins/7133', 'https://kohawkathletics.com//sports/wrestling/roster/lauden-edwards/7134', 'https://kohawkathletics.com//sports/wrestling/roster/will-esmoil/7108', 'https://kohawkathletics.com//sports/wrestling/roster/dylan-falck/7109', 'https://kohawkathletics.com//sports/wrestling/roster/alex-friddle/7110', 'https://kohawkathletics.com//sports/wrestling/roster/anthony-gallagher/7217', 'https://kohawkathletics.com//sports/wrestling/roster/dylan-grigsby/7111', 'https://kohawkathletics.com//sports/wrestling/roster/brady-henderson/7112', 'https://kohawkathletics.com//sports/wrestling/roster/brock-henderson/7113', 'https://kohawkathletics.com//sports/wrestling/roster/kole-kreinbring/7114', 'https://kohawkathletics.com//sports/wrestling/roster/ryker-kurimski/7115', 'https://kohawkathletics.com//sports/wrestling/roster/cael-long/7138', 'https://kohawkathletics.com//sports/wrestling/roster/noah-mirelez/7118', 'https://kohawkathletics.com//sports/wrestling/roster/grifen-molle/7139', 'https://kohawkathletics.com//sports/wrestling/roster/bryce-parke/7140', 'https://kohawkathletics.com//sports/wrestling/roster/aj-patterson/7120', 'https://kohawkathletics.com//sports/wrestling/roster/kaleb-reeves/7121', 'https://kohawkathletics.com//sports/wrestling/roster/camron-reilly/7136', 'https://kohawkathletics.com//sports/wrestling/roster/lj-richardson/7137', 'https://kohawkathletics.com//sports/wrestling/roster/ryan-schott/7123', 'https://kohawkathletics.com//sports/wrestling/roster/jack-sindlinger/7126', 'https://kohawkathletics.com//sports/wrestling/roster/guy-snow/7127', 'https://kohawkathletics.com//sports/wrestling/roster/jared-voss/7141', 'https://kohawkathletics.com//sports/wrestling/roster/tristin-westphal/7129', 'https://kohawkathletics.com//sports/wrestling/roster/riley-wright/7130']

# %% [markdown]
# ## Compiling the script: test

# %%
wrestler_list=[]
for link in playerlinks:
    r=requests.get(link, headers=headers)
    soup=BeautifulSoup(r.content,'html.parser')
    
    fl_name=soup.find('span', class_='sidearm-roster-player-name').text.replace('\n',' ').strip()
    
    try:
        weight=soup.findAll('dl', class_='flex-item-1')[0].text.replace('\n',' ').strip()
    except:
        weight=None
    
    try:
        s_class=soup.findAll('dl', class_='flex-item-1')[1].text.replace('\n',' ').strip()
    except:
        s_class=None    
    
    try:
        city_home=soup.findAll('dl', class_='flex-item-1')[2].text.replace('\n',' ').strip()
    except:
        city_home=None
        
    try:
        hs=soup.findAll('dl', class_='flex-item-1')[3].text.replace('\n',' ').strip()
    except:
        hs=None
    
    w_stats = {
        "Name":fl_name,
        "Weight_class":weight,
        "Class":s_class,
        "Hometown":city_home,
        "Highschool":hs
        }
    
    wrestler_list.append(w_stats)
    print('saving :', w_stats['Name'])
# Out:
# saving : Logan Andeway
# saving : Mathieu Arsenault
# saving : Wyatt Bieschke
# saving : Aaron Castellanos
# saving : Patrick Chambers
# saving : Stone Cummins
# saving : Lauden Edwards
# saving : Will  Esmoil
# saving : Dylan  Falck
# saving : Alex Friddle
# saving : Anthony Gallagher
# saving : Dylan Grigsby
# saving : Brady Henderson
# saving : Brock Henderson
# saving : Kole Kreinbring
# saving : Ryker Kurimski
# saving : Cael Long
# saving : Noah Mirelez
# saving : Grifen Molle
# saving : Bryce Parke
# saving : AJ Patterson
# saving : Kaleb Reeves
# saving : Camron Reilly
# saving : LJ Richardson
# saving : Ryan Schott
# saving : Jack  Sindlinger
# saving : Guy Snow
# saving : Jared Voss
# saving : Tristin Westphal
# saving : Riley Wright

# %%
df=pd.DataFrame(wrestler_list)

# %%
df.head()
# Out:
#                 Name     Weight_class                      Class  \
# 0      Logan Andeway       Weight 184               Class Junior
# 1  Mathieu Arsenault   Class Freshman  Hometown Plainfield, Ill.
# 2     Wyatt Bieschke  Class Sophomore     Hometown Marengo, Iowa
# 3  Aaron Castellanos       Weight 133               Class Senior
# 4   Patrick Chambers       Weight 149               Class Junior
#
#                       Hometown                Highschool
# 0  Hometown Cedar Rapids, Iowa        Highschool Prairie
# 1                         None                      None
# 2  Highschool Benton Community                      None
# 3    Hometown Glen Ellyn, Ill.  Highschool Glenbard West
# 4  Hometown Cedar Rapids, Iowa         Highschool Xavier

# %%
df
# Out:
#                  Name     Weight_class                        Class  \
# 0       Logan Andeway       Weight 184                 Class Junior
# 1   Mathieu Arsenault   Class Freshman    Hometown Plainfield, Ill.
# 2      Wyatt Bieschke  Class Sophomore       Hometown Marengo, Iowa
# 3   Aaron Castellanos       Weight 133                 Class Senior
# 4    Patrick Chambers       Weight 149                 Class Junior
# 5       Stone Cummins   Class Freshman        Hometown Clinton, TN.
# 6      Lauden Edwards   Class Freshman  Hometown Carol Stream, Ill.
# 7        Will  Esmoil  Class Sophomore  Hometown West Liberty, Iowa
# 8        Dylan  Falck  Class Sophomore  Hometown Cedar Rapids, Iowa
# 9        Alex Friddle       Weight 125                 Class Junior
# 10  Anthony Gallagher     Class Senior                         None
# 11      Dylan Grigsby  Class Sophomore    Hometown Canton, Illinois
# 12    Brady Henderson       Weight 149                 Class Junior
# 13    Brock Henderson       Weight 133                 Class Senior
# 14    Kole Kreinbring       Weight 184                 Class Junior
# 15     Ryker Kurimski       Weight 165                 Class Junior
# 16          Cael Long   Class Freshman  Hometown Cedar Rapids, Iowa
# 17       Noah Mirelez  Class Sophomore      Hometown Patterson, CA.
# 18       Grifen Molle   Class Freshman      Hometown Danville, Iowa
# 19        Bryce Parke   Class Freshman        Hometown Marion, Iowa
# 20       AJ Patterson       Weight 149                 Class Senior
# 21       Kaleb Reeves       Weight 285                 Class Senior
# 22      Camron Reilly   Class Freshman         Hometown Rosebud, MT
# 23      LJ Richardson   Class Freshman      Hometown Prosper, Texas
# 24        Ryan Schott       Weight 174                 Class Senior
# 25   Jack  Sindlinger  Class Sophomore  Hometown Charles City, iowa
# 26           Guy Snow       Weight 285                 Class Senior
# 27         Jared Voss   Class Freshman          Hometown Ryan, Iowa
# 28   Tristin Westphal       Weight 174                 Class Junior
# 29       Riley Wright       Weight 141                 Class Junior
#
#                        Hometown                   Highschool
# 0   Hometown Cedar Rapids, Iowa           Highschool Prairie
# 1                          None                         None
# 2   Highschool Benton Community                         None
# 3     Hometown Glen Ellyn, Ill.     Highschool Glenbard West
# 4   Hometown Cedar Rapids, Iowa            Highschool Xavier
# 5    Highschool Anderson County                         None
# 6                          None                         None
# 7       Highschool West Liberty                         None
# 8            Highschool Kennedy                         None
# 9         Hometown Morris, Ill.         Highschool Coal City
# 10                         None                         None
# 11            Highschool Canton                         None
# 12        Hometown Coggon, Iowa        Highschool North Linn
# 13        Hometown Coggon, Iowa        Highschool North Linn
# 14     Hometown Davenport, Iowa        Highschool Assumption
# 15       Hometown Epworth, Iowa   Highschool Western Dubuque
# 16           Highschool Kennedy                         None
# 17         Highschool Patterson                         None
# 18   Highschool West Burlington                         None
# 19                         None                         None
# 20     Hometown New Lenox, Ill.  Highschool Lincoln-Way West
# 21     Hometown Sigourney, Iowa         Highschool Sigourney
# 22                         None                         None
# 23                         None                         None
# 24     Hometown Iowa City, Iowa            Highschool Regina
# 25      Highschool Charles City                         None
# 26     Hometown Iowa City, Iowa              Highschool West
# 27                         None                         None
# 28    Hometown Washington, Iowa        Highschool Washington
# 29        Hometown Denver, Iowa            Highschool Denver

# %%
df.to_csv('Kohawks_Roster.csv')
